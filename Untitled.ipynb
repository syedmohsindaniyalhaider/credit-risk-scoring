# %%
#import libraries
import pandas as pd
import numpy as np
import time
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read csv
df = pd.read_csv('IGP.csv')
df
# Out:
#        Unnamed: 0               Company name Credit score Credit score date  \
# 0             1.0                  SHELL PLC           95        26-09-2023
# 1             2.0                  BP P.L.C.           95        27-11-2023
# 2             3.0    GLENCORE ENERGY UK LTD.           85        29-09-2023
# 3             4.0               UNILEVER PLC           95        11-01-2024
# 4             5.0              RIO TINTO PLC           99        26-09-2023
# ...           ...                        ...          ...               ...
# 19995     19996.0  IMPACT PROPERTY 7 LIMITED           89        21-07-2023
# 19996     19997.0         R.A.H.M.S. LIMITED           97        25-09-2023
# 19997     19998.0       FTSE (JAPAN) LIMITED           89        11-10-2023
# 19998     19999.0            RUNBARO LIMITED           77        11-08-2023
# 19999     20000.0       COVER GENIUS LIMITED           88        14-09-2023
#
#       Credit limit\nGBP Likelihood of failure\n%  \
# 0                  n.a.                      0.9
# 1           5,00,00,000                      0.9
# 2           1,94,58,000                      0.9
# 3           5,00,00,000                      0.9
# 4           5,00,00,000                      0.9
# ...                 ...                      ...
# 19995          9,50,940                      0.9
# 19996          1,27,860                      1.0
# 19997          2,30,652                      0.9
# 19998               500                      2.2
# 19999          6,25,553                      0.9
#
#       Profit margin\nLast avail. yr Gross margin\nLast avail. yr  \
# 0                             16.78                          NaN
# 1                              6.19                          NaN
# 2                              0.23                         1.35
# 3                             17.21                        40.23
# 4                             33.59                          NaN
# ...                             ...                          ...
# 19995                         66.12                          NaN
# 19996                         17.03                          NaN
# 19997                         28.05                        96.77
# 19998                        -40.25                        91.26
# 19999                         43.11                          NaN
#
#       Debtor Collection\nLast avail. yr Creditors Payment\nLast avail. yr  \
# 0                                 37.17                             40.29
# 1                                 41.40                             69.23
# 2                                 23.42                             27.19
# 3                                 27.61                             67.44
# 4                                 14.32                             21.48
# ...                                 ...                               ...
# 19995                               NaN                               NaN
# 19996                              8.24                              2.92
# 19997                               NaN                              0.29
# 19998                              5.91                             11.94
# 19999                            940.86                            442.68
#
#        ... Turnover\nth GBP Year - 2 Turnover\nth GBP Year - 3  \
# 0      ...              13,40,81,000              26,53,80,000
# 1      ...              13,43,04,000              21,30,06,000
# 2      ...               2,82,65,176               5,42,08,695
# 3      ...               4,53,95,000               4,39,87,000
# 4      ...               3,26,51,000               3,25,33,000
# ...    ...                       ...                       ...
# 19995  ...                      n.a.                      n.a.
# 19996  ...                       NaN                       NaN
# 19997  ...                     3,614                     3,336
# 19998  ...                     1,988                     5,681
# 19999  ...                     2,548                     2,757
#
#       Total Assets\nth GBP Last avail. yr Total Assets\nth GBP Year - 1  \
# 0                            36,60,90,000                  29,87,44,000
# 1                            23,80,86,000                  21,22,28,000
# 2                             1,25,50,765                     96,93,081
# 3                             6,89,11,000                   6,31,16,000
# 4                             7,99,44,000                   7,60,17,000
# ...                                   ...                           ...
# 19995                              66,077                        64,025
# 19996                               4,598                         4,502
# 19997                               5,303                         7,262
# 19998                               6,419                         7,539
# 19999                              38,563                         7,231
#
#       Total Assets\nth GBP Year - 2 Total Assets\nth GBP Year - 3  \
# 0                      27,75,88,000                  30,47,45,000
# 1                      19,58,97,000                  22,24,85,000
# 2                         54,42,881                     68,15,203
# 3                       6,05,50,000                   5,48,42,000
# 4                       7,12,80,000                   6,61,76,000
# ...                             ...                           ...
# 19995                          n.a.                          n.a.
# 19996                         4,203                         4,545
# 19997                         5,215                         4,559
# 19998                         7,978                         8,370
# 19999                         3,234                         7,137
#
#       Number of employees\nLast avail. yr Number of employees\nYear - 1  \
# 0                                  87,000                        82,000
# 1                                  66,300                        64,000
# 2                                     492                           474
# 3                                1,38,000                      1,49,000
# 4                                  53,726                        49,345
# ...                                   ...                           ...
# 19995                                 NaN                           NaN
# 19996                                  22                            22
# 19997                                  18                            15
# 19998                                 101                           101
# 19999                                 NaN                            21
#
#       Number of employees\nYear - 2 Number of employees\nYear - 3
# 0                            86,000                        83,000
# 1                            68,100                        72,500
# 2                               443                           419
# 3                          1,50,000                      1,53,000
# 4                            47,474                        46,007
# ...                             ...                           ...
# 19995                          n.a.                          n.a.
# 19996                            23                            24
# 19997                            14                            13
# 19998                            96                           122
# 19999                            20                            19
#
# [20000 rows x 35 columns]

# %%
#check datatype 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 35 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Unnamed: 0                                           20000 non-null  float64
#  1   Company name                                         20000 non-null  object
#  2   Credit score                                         20000 non-null  object
#  3   Credit score date                                    18431 non-null  object
#  4   Credit limit
# GBP                                     20000 non-null  object
#  5   Likelihood of failure
# %                              20000 non-null  object
#  6   Profit margin
# Last avail. yr                         19388 non-null  object
#  7   Gross margin
# Last avail. yr                          13899 non-null  object
#  8   Debtor Collection
# Last avail. yr                     14910 non-null  object
#  9   Creditors Payment
# Last avail. yr                     16108 non-null  object
#  10  Current ratio (x)
# Last avail. yr                     19387 non-null  object
#  11  Liquidity ratio (x)
# Last avail. yr                   19387 non-null  object
#  12  Gearing
# Last avail. yr                               17627 non-null  object
#  13  Return on Total Assets
# Last avail. yr                19385 non-null  object
#  14  Company status                                       20000 non-null  object
#  15  Profit (Loss) before Taxation
# th GBP Last avail. yr  19388 non-null  object
#  16  Profit (Loss) before Taxation
# th GBP Year - 1        18610 non-null  object
#  17  Profit (Loss) before Taxation
# th GBP Year - 2        18137 non-null  object
#  18  Profit (Loss) before Taxation
# th GBP Year - 3        17774 non-null  object
#  19  Profit (Loss) after Tax
# th GBP Last avail. yr        19433 non-null  object
#  20  Profit (Loss) after Tax
# th GBP Year - 1              18650 non-null  object
#  21  Profit (Loss) after Tax
# th GBP Year - 2              18188 non-null  object
#  22  Profit (Loss) after Tax
# th GBP Year - 3              17801 non-null  object
#  23  Turnover
# th GBP Last avail. yr                       20000 non-null  object
#  24  Turnover
# th GBP Year - 1                             18820 non-null  object
#  25  Turnover
# th GBP Year - 2                             18189 non-null  object
#  26  Turnover
# th GBP Year - 3                             17774 non-null  object
#  27  Total Assets
# th GBP Last avail. yr                   19898 non-null  object
#  28  Total Assets
# th GBP Year - 1                         19970 non-null  object
#  29  Total Assets
# th GBP Year - 2                         19941 non-null  object
#  30  Total Assets
# th GBP Year - 3                         19968 non-null  object
#  31  Number of employees
# Last avail. yr                   15681 non-null  object
#  32  Number of employees
# Year - 1                         15746 non-null  object
#  33  Number of employees
# Year - 2                         15936 non-null  object
#  34  Number of employees
# Year - 3                         16390 non-null  object
# dtypes: float64(1), object(34)
# memory usage: 5.3+ MB

# %%
#correct columns names 
names = {
    'Unnamed: 0' : 'ID',
    'Credit limit\nGBP' : 'Credit limit',
    'Likelihood of failure\n%' : 'Likelihood of failure(%)',
    'Profit margin\nLast avail. yr': 'Profit Margin',
    'Gross margin\nLast avail. yr': 'Gross Margin',
    'Debtor Collection\nLast avail. yr': 'Debtor Collection',
    'Creditors Payment\nLast avail. yr': 'Creditors Payment',
    'Current ratio (x)\nLast avail. yr': 'Current Ratio',
    'Liquidity ratio (x)\nLast avail. yr': 'Liquidity Ratio',
    'Gearing\nLast avail. yr': 'Gearing',
    'Return on Total Assets\nLast avail. yr': 'Return on Total Assets',
    'Profit (Loss) before Taxation\nth GBP Last avail. yr': 'Profit before Tax',
    'Profit (Loss) before Taxation\nth GBP Year - 1': 'Profit before Tax for year1',
    'Profit (Loss) before Taxation\nth GBP Year - 2': 'Profit before Tax for year2',
    'Profit (Loss) before Taxation\nth GBP Year - 3': 'Profit before Tax for year3',
    'Profit (Loss) after Tax\nth GBP Last avail. yr': 'Profit after Tax',
    'Profit (Loss) after Tax\nth GBP Year - 1': 'Profit after Tax for year1',
    'Profit (Loss) after Tax\nth GBP Year - 2': 'Profit after Tax for year2',
    'Profit (Loss) after Tax\nth GBP Year - 3': 'Profit after Tax for year3',
    'Turnover\nth GBP Last avail. yr': 'Turnover',
    'Turnover\nth GBP Year - 1': 'Turnover in year1',
    'Turnover\nth GBP Year - 2': 'Turnover in year2',
    'Turnover\nth GBP Year - 3': 'Turnover in year3',
    'Total Assets\nth GBP Last avail. yr': 'Total Assets',
    'Total Assets\nth GBP Year - 1': 'Total Assets of year1',
    'Total Assets\nth GBP Year - 2': 'Total Assets of year2',
    'Total Assets\nth GBP Year - 3': 'Total Assets of year3',
    'Number of employees\nLast avail. yr': 'Number of Employees',
    'Number of employees\nYear - 1': 'Number of Employees in year1',
    'Number of employees\nYear - 2': 'Number of Employees in year2',
    'Number of employees\nYear - 3': 'Number of Employees in year3'
}
df.rename(columns=names, inplace=True)
df
# Out:
#             ID               Company name Credit score Credit score date  \
# 0          1.0                  SHELL PLC           95        26-09-2023
# 1          2.0                  BP P.L.C.           95        27-11-2023
# 2          3.0    GLENCORE ENERGY UK LTD.           85        29-09-2023
# 3          4.0               UNILEVER PLC           95        11-01-2024
# 4          5.0              RIO TINTO PLC           99        26-09-2023
# ...        ...                        ...          ...               ...
# 19995  19996.0  IMPACT PROPERTY 7 LIMITED           89        21-07-2023
# 19996  19997.0         R.A.H.M.S. LIMITED           97        25-09-2023
# 19997  19998.0       FTSE (JAPAN) LIMITED           89        11-10-2023
# 19998  19999.0            RUNBARO LIMITED           77        11-08-2023
# 19999  20000.0       COVER GENIUS LIMITED           88        14-09-2023
#
#       Credit limit Likelihood of failure(%) Profit Margin Gross Margin  \
# 0             n.a.                      0.9         16.78          NaN
# 1      5,00,00,000                      0.9          6.19          NaN
# 2      1,94,58,000                      0.9          0.23         1.35
# 3      5,00,00,000                      0.9         17.21        40.23
# 4      5,00,00,000                      0.9         33.59          NaN
# ...            ...                      ...           ...          ...
# 19995     9,50,940                      0.9         66.12          NaN
# 19996     1,27,860                      1.0         17.03          NaN
# 19997     2,30,652                      0.9         28.05        96.77
# 19998          500                      2.2        -40.25        91.26
# 19999     6,25,553                      0.9         43.11          NaN
#
#       Debtor Collection Creditors Payment  ... Turnover in year2  \
# 0                 37.17             40.29  ...      13,40,81,000
# 1                 41.40             69.23  ...      13,43,04,000
# 2                 23.42             27.19  ...       2,82,65,176
# 3                 27.61             67.44  ...       4,53,95,000
# 4                 14.32             21.48  ...       3,26,51,000
# ...                 ...               ...  ...               ...
# 19995               NaN               NaN  ...              n.a.
# 19996              8.24              2.92  ...               NaN
# 19997               NaN              0.29  ...             3,614
# 19998              5.91             11.94  ...             1,988
# 19999            940.86            442.68  ...             2,548
#
#       Turnover in year3  Total Assets Total Assets of year1  \
# 0          26,53,80,000  36,60,90,000          29,87,44,000
# 1          21,30,06,000  23,80,86,000          21,22,28,000
# 2           5,42,08,695   1,25,50,765             96,93,081
# 3           4,39,87,000   6,89,11,000           6,31,16,000
# 4           3,25,33,000   7,99,44,000           7,60,17,000
# ...                 ...           ...                   ...
# 19995              n.a.        66,077                64,025
# 19996               NaN         4,598                 4,502
# 19997             3,336         5,303                 7,262
# 19998             5,681         6,419                 7,539
# 19999             2,757        38,563                 7,231
#
#       Total Assets of year2 Total Assets of year3 Number of Employees  \
# 0              27,75,88,000          30,47,45,000              87,000
# 1              19,58,97,000          22,24,85,000              66,300
# 2                 54,42,881             68,15,203                 492
# 3               6,05,50,000           5,48,42,000            1,38,000
# 4               7,12,80,000           6,61,76,000              53,726
# ...                     ...                   ...                 ...
# 19995                  n.a.                  n.a.                 NaN
# 19996                 4,203                 4,545                  22
# 19997                 5,215                 4,559                  18
# 19998                 7,978                 8,370                 101
# 19999                 3,234                 7,137                 NaN
#
#       Number of Employees in year1 Number of Employees in year2  \
# 0                           82,000                       86,000
# 1                           64,000                       68,100
# 2                              474                          443
# 3                         1,49,000                     1,50,000
# 4                           49,345                       47,474
# ...                            ...                          ...
# 19995                          NaN                         n.a.
# 19996                           22                           23
# 19997                           15                           14
# 19998                          101                           96
# 19999                           21                           20
#
#       Number of Employees in year3
# 0                           83,000
# 1                           72,500
# 2                              419
# 3                         1,53,000
# 4                           46,007
# ...                            ...
# 19995                         n.a.
# 19996                           24
# 19997                           13
# 19998                          122
# 19999                           19
#
# [20000 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            20000 non-null  float64
#  1   Company name                  20000 non-null  object
#  2   Credit score                  20000 non-null  object
#  3   Credit score date             18431 non-null  object
#  4   Credit limit                  20000 non-null  object
#  5   Likelihood of failure(%)      20000 non-null  object
#  6   Profit Margin                 19388 non-null  object
#  7   Gross Margin                  13899 non-null  object
#  8   Debtor Collection             14910 non-null  object
#  9   Creditors Payment             16108 non-null  object
#  10  Current Ratio                 19387 non-null  object
#  11  Liquidity Ratio               19387 non-null  object
#  12  Gearing                       17627 non-null  object
#  13  Return on Total Assets        19385 non-null  object
#  14  Company status                20000 non-null  object
#  15  Profit before Tax             19388 non-null  object
#  16  Profit before Tax for year1   18610 non-null  object
#  17  Profit before Tax for year2   18137 non-null  object
#  18  Profit before Tax for year3   17774 non-null  object
#  19  Profit after Tax              19433 non-null  object
#  20  Profit after Tax for year1    18650 non-null  object
#  21  Profit after Tax for year2    18188 non-null  object
#  22  Profit after Tax for year3    17801 non-null  object
#  23  Turnover                      20000 non-null  object
#  24  Turnover in year1             18820 non-null  object
#  25  Turnover in year2             18189 non-null  object
#  26  Turnover in year3             17774 non-null  object
#  27  Total Assets                  19898 non-null  object
#  28  Total Assets of year1         19970 non-null  object
#  29  Total Assets of year2         19941 non-null  object
#  30  Total Assets of year3         19968 non-null  object
#  31  Number of Employees           15681 non-null  object
#  32  Number of Employees in year1  15746 non-null  object
#  33  Number of Employees in year2  15936 non-null  object
#  34  Number of Employees in year3  16390 non-null  object
# dtypes: float64(1), object(34)
# memory usage: 5.3+ MB

# %%
output_file = ("IGP1.csv")
df.to_csv(output_file, index=False)

# %%
##check missing values
df1 = df[pd.isna(df['Credit score date'])]
df1
# Out:
#             ID                            Company name Credit score  \
# 27        28.0           INSTANT BRANDS (EMEA) LIMITED         n.a.
# 100      101.0                    REED ELSEVIER PLC/NV         n.a.
# 114      115.0                      TXU EUROPE LIMITED         n.a.
# 154      155.0             LIBERTY COMMODITIES LIMITED         n.a.
# 265      266.0  DEPARTMENT STORES REALISATIONS LIMITED         n.a.
# ...        ...                                     ...          ...
# 19971  19972.0                      INEVIDENCE LIMITED         n.a.
# 19976  19977.0       S.W. FARMER & SON (LEEDS) LIMITED         n.a.
# 19977  19978.0                COTESBACH ENERGY LIMITED         n.a.
# 19981  19982.0                   CLPE ROC - 3A LIMITED         n.a.
# 19982  19983.0             THE ROYAL ALBERT HALL TRUST         n.a.
#
#       Credit score date Credit limit Likelihood of failure(%) Profit Margin  \
# 27                  NaN         n.a.                     n.a.          2.80
# 100                 NaN         n.a.                     n.a.         21.29
# 114                 NaN         n.a.                     n.a.          0.90
# 154                 NaN         n.a.                     n.a.          0.21
# 265                 NaN         n.a.                     n.a.        -11.73
# ...                 ...          ...                      ...           ...
# 19971               NaN         n.a.                     n.a.         21.84
# 19976               NaN         n.a.                     n.a.          0.50
# 19977               NaN         n.a.                     n.a.         12.26
# 19981               NaN         n.a.                     n.a.          7.40
# 19982               NaN         n.a.                     n.a.           NaN
#
#       Gross Margin Debtor Collection Creditors Payment  ... Turnover in year2  \
# 27           17.64            152.19             55.42  ...               NaN
# 100          65.25             82.89             21.05  ...         61,16,000
# 114          24.61             42.19             51.35  ...         21,69,000
# 154           2.07             15.75              4.02  ...         30,10,692
# 265          -3.10              3.64             69.22  ...         21,05,400
# ...            ...               ...               ...  ...               ...
# 19971        78.74             69.17             15.57  ...             3,291
# 19976          NaN             30.00             65.25  ...             2,655
# 19977        16.55              1.68               NaN  ...             3,652
# 19981        19.42              1.89               NaN  ...             3,566
# 19982          NaN               NaN               NaN  ...             2,023
#
#       Turnover in year3 Total Assets Total Assets of year1  \
# 27                  NaN  2,34,05,583                 4,681
# 100           60,02,000  1,10,87,000           1,04,95,000
# 114                n.a.    98,24,500             76,71,000
# 154           31,55,738     2,14,478              2,60,998
# 265           20,99,300    29,07,300             28,67,300
# ...                 ...          ...                   ...
# 19971             4,141        8,298                 6,587
# 19976             3,491        1,606                 1,275
# 19977             4,023        1,951                 1,302
# 19981             4,592        1,516                 1,340
# 19982             2,828        1,803                   568
#
#       Total Assets of year2 Total Assets of year3 Number of Employees  \
# 27                    2,941                   581                  22
# 100             1,10,14,000           1,15,03,000              28,500
# 114               69,69,600                  n.a.               4,806
# 154                2,98,870              2,66,022                  13
# 265               27,17,100             25,19,600              22,283
# ...                     ...                   ...                 ...
# 19971                 4,813                 4,122                  41
# 19976                 1,863                 1,092                 113
# 19977                 1,810                 1,972                 NaN
# 19981                 1,304                 1,256                 NaN
# 19982                   939                 1,099                 NaN
#
#       Number of Employees in year1 Number of Employees in year2  \
# 27                               5                            2
# 100                         28,200                       30,500
# 114                          6,729                        7,233
# 154                             14                           30
# 265                         23,727                       24,545
# ...                            ...                          ...
# 19971                           38                           34
# 19976                           96                           82
# 19977                          NaN                          NaN
# 19981                          NaN                            3
# 19982                          NaN                          NaN
#
#       Number of Employees in year3
# 27                               2
# 100                         30,600
# 114                           n.a.
# 154                             18
# 265                         24,806
# ...                            ...
# 19971                           34
# 19976                           78
# 19977                            3
# 19981                            3
# 19982                          NaN
#
# [1569 rows x 35 columns]

# %%
##remove missing values
df2 = df.dropna(subset=['Credit score date'])
df2
# Out:
#             ID               Company name Credit score Credit score date  \
# 0          1.0                  SHELL PLC           95        26-09-2023
# 1          2.0                  BP P.L.C.           95        27-11-2023
# 2          3.0    GLENCORE ENERGY UK LTD.           85        29-09-2023
# 3          4.0               UNILEVER PLC           95        11-01-2024
# 4          5.0              RIO TINTO PLC           99        26-09-2023
# ...        ...                        ...          ...               ...
# 19995  19996.0  IMPACT PROPERTY 7 LIMITED           89        21-07-2023
# 19996  19997.0         R.A.H.M.S. LIMITED           97        25-09-2023
# 19997  19998.0       FTSE (JAPAN) LIMITED           89        11-10-2023
# 19998  19999.0            RUNBARO LIMITED           77        11-08-2023
# 19999  20000.0       COVER GENIUS LIMITED           88        14-09-2023
#
#       Credit limit Likelihood of failure(%) Profit Margin Gross Margin  \
# 0             n.a.                      0.9         16.78          NaN
# 1      5,00,00,000                      0.9          6.19          NaN
# 2      1,94,58,000                      0.9          0.23         1.35
# 3      5,00,00,000                      0.9         17.21        40.23
# 4      5,00,00,000                      0.9         33.59          NaN
# ...            ...                      ...           ...          ...
# 19995     9,50,940                      0.9         66.12          NaN
# 19996     1,27,860                      1.0         17.03          NaN
# 19997     2,30,652                      0.9         28.05        96.77
# 19998          500                      2.2        -40.25        91.26
# 19999     6,25,553                      0.9         43.11          NaN
#
#       Debtor Collection Creditors Payment  ... Turnover in year2  \
# 0                 37.17             40.29  ...      13,40,81,000
# 1                 41.40             69.23  ...      13,43,04,000
# 2                 23.42             27.19  ...       2,82,65,176
# 3                 27.61             67.44  ...       4,53,95,000
# 4                 14.32             21.48  ...       3,26,51,000
# ...                 ...               ...  ...               ...
# 19995               NaN               NaN  ...              n.a.
# 19996              8.24              2.92  ...               NaN
# 19997               NaN              0.29  ...             3,614
# 19998              5.91             11.94  ...             1,988
# 19999            940.86            442.68  ...             2,548
#
#       Turnover in year3  Total Assets Total Assets of year1  \
# 0          26,53,80,000  36,60,90,000          29,87,44,000
# 1          21,30,06,000  23,80,86,000          21,22,28,000
# 2           5,42,08,695   1,25,50,765             96,93,081
# 3           4,39,87,000   6,89,11,000           6,31,16,000
# 4           3,25,33,000   7,99,44,000           7,60,17,000
# ...                 ...           ...                   ...
# 19995              n.a.        66,077                64,025
# 19996               NaN         4,598                 4,502
# 19997             3,336         5,303                 7,262
# 19998             5,681         6,419                 7,539
# 19999             2,757        38,563                 7,231
#
#       Total Assets of year2 Total Assets of year3 Number of Employees  \
# 0              27,75,88,000          30,47,45,000              87,000
# 1              19,58,97,000          22,24,85,000              66,300
# 2                 54,42,881             68,15,203                 492
# 3               6,05,50,000           5,48,42,000            1,38,000
# 4               7,12,80,000           6,61,76,000              53,726
# ...                     ...                   ...                 ...
# 19995                  n.a.                  n.a.                 NaN
# 19996                 4,203                 4,545                  22
# 19997                 5,215                 4,559                  18
# 19998                 7,978                 8,370                 101
# 19999                 3,234                 7,137                 NaN
#
#       Number of Employees in year1 Number of Employees in year2  \
# 0                           82,000                       86,000
# 1                           64,000                       68,100
# 2                              474                          443
# 3                         1,49,000                     1,50,000
# 4                           49,345                       47,474
# ...                            ...                          ...
# 19995                          NaN                         n.a.
# 19996                           22                           23
# 19997                           15                           14
# 19998                          101                           96
# 19999                           21                           20
#
#       Number of Employees in year3
# 0                           83,000
# 1                           72,500
# 2                              419
# 3                         1,53,000
# 4                           46,007
# ...                            ...
# 19995                         n.a.
# 19996                           24
# 19997                           13
# 19998                          122
# 19999                           19
#
# [18431 rows x 35 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18431 entries, 0 to 19999
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            18431 non-null  float64
#  1   Company name                  18431 non-null  object
#  2   Credit score                  18431 non-null  object
#  3   Credit score date             18431 non-null  object
#  4   Credit limit                  18431 non-null  object
#  5   Likelihood of failure(%)      18431 non-null  object
#  6   Profit Margin                 18229 non-null  object
#  7   Gross Margin                  12933 non-null  object
#  8   Debtor Collection             13960 non-null  object
#  9   Creditors Payment             15158 non-null  object
#  10  Current Ratio                 18247 non-null  object
#  11  Liquidity Ratio               18247 non-null  object
#  12  Gearing                       16547 non-null  object
#  13  Return on Total Assets        18226 non-null  object
#  14  Company status                18431 non-null  object
#  15  Profit before Tax             18229 non-null  object
#  16  Profit before Tax for year1   17408 non-null  object
#  17  Profit before Tax for year2   16946 non-null  object
#  18  Profit before Tax for year3   16581 non-null  object
#  19  Profit after Tax              18267 non-null  object
#  20  Profit after Tax for year1    17444 non-null  object
#  21  Profit after Tax for year2    16996 non-null  object
#  22  Profit after Tax for year3    16608 non-null  object
#  23  Turnover                      18431 non-null  object
#  24  Turnover in year1             17337 non-null  object
#  25  Turnover in year2             16748 non-null  object
#  26  Turnover in year3             16345 non-null  object
#  27  Total Assets                  18408 non-null  object
#  28  Total Assets of year1         18401 non-null  object
#  29  Total Assets of year2         18373 non-null  object
#  30  Total Assets of year3         18401 non-null  object
#  31  Number of Employees           14541 non-null  object
#  32  Number of Employees in year1  14482 non-null  object
#  33  Number of Employees in year2  14666 non-null  object
#  34  Number of Employees in year3  15081 non-null  object
# dtypes: float64(1), object(34)
# memory usage: 5.1+ MB

# %%
# Replace 'n.a.' and 'n.s.' with NaN
df2.replace(['n.a.', 'n.s.'], float('nan'), inplace=True)

# Convert remaining NaN values to 0 
df2.fillna(0, inplace=True)  

# Convert numeric columns to integers
numeric_columns = df2.select_dtypes(include=['float64', 'int64']).columns

df2[numeric_columns] = df2[numeric_columns].astype(int)
# Out:
# C:\Users\Arth\AppData\Local\Temp\ipykernel_27036\3147158855.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.replace(['n.a.', 'n.s.'], float('nan'), inplace=True)
# C:\Users\Arth\AppData\Local\Temp\ipykernel_27036\3147158855.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.fillna(0, inplace=True)  # or df.fillna(1, inplace=True) to replace with 1 instead
# C:\Users\Arth\AppData\Local\Temp\ipykernel_27036\3147158855.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[numeric_columns] = df2[numeric_columns].astype(int)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18431 entries, 0 to 19999
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            18431 non-null  int32
#  1   Company name                  18431 non-null  object
#  2   Credit score                  18431 non-null  object
#  3   Credit score date             18431 non-null  object
#  4   Credit limit                  18431 non-null  object
#  5   Likelihood of failure(%)      18431 non-null  object
#  6   Profit Margin                 18431 non-null  object
#  7   Gross Margin                  18431 non-null  object
#  8   Debtor Collection             18431 non-null  object
#  9   Creditors Payment             18431 non-null  object
#  10  Current Ratio                 18431 non-null  object
#  11  Liquidity Ratio               18431 non-null  object
#  12  Gearing                       18431 non-null  object
#  13  Return on Total Assets        18431 non-null  object
#  14  Company status                18431 non-null  object
#  15  Profit before Tax             18431 non-null  object
#  16  Profit before Tax for year1   18431 non-null  object
#  17  Profit before Tax for year2   18431 non-null  object
#  18  Profit before Tax for year3   18431 non-null  object
#  19  Profit after Tax              18431 non-null  object
#  20  Profit after Tax for year1    18431 non-null  object
#  21  Profit after Tax for year2    18431 non-null  object
#  22  Profit after Tax for year3    18431 non-null  object
#  23  Turnover                      18431 non-null  object
#  24  Turnover in year1             18431 non-null  object
#  25  Turnover in year2             18431 non-null  object
#  26  Turnover in year3             18431 non-null  object
#  27  Total Assets                  18431 non-null  object
#  28  Total Assets of year1         18431 non-null  object
#  29  Total Assets of year2         18431 non-null  object
#  30  Total Assets of year3         18431 non-null  object
#  31  Number of Employees           18431 non-null  object
#  32  Number of Employees in year1  18431 non-null  object
#  33  Number of Employees in year2  18431 non-null  object
#  34  Number of Employees in year3  18431 non-null  object
# dtypes: int32(1), object(34)
# memory usage: 5.0+ MB

# %%
# Out:
#       ID                               Company name Credit score  \
# 0      1                                  SHELL PLC           95
# 1      2                                  BP P.L.C.           95
# 2      3                    GLENCORE ENERGY UK LTD.           85
# 3      4                               UNILEVER PLC           95
# 4      5                              RIO TINTO PLC           99
# ..   ...                                        ...          ...
# 199  200                              RUBIX LIMITED           89
# 200  201                 EY GLOBAL SERVICES LIMITED           77
# 201  202                    EVRAZ NORTH AMERICA PLC           95
# 202  203  DELOITTE GLOBAL SERVICES HOLDINGS LIMITED           86
# 203  204           DELOITTE GLOBAL SERVICES LIMITED           81
#
#     Credit score date Credit limit Likelihood of failure(%) Profit Margin  \
# 0          26-09-2023            0                      0.9         16.78
# 1          27-11-2023  5,00,00,000                      0.9          6.19
# 2          29-09-2023  1,94,58,000                      0.9          0.23
# 3          11-01-2024  5,00,00,000                      0.9         17.21
# 4          26-09-2023  5,00,00,000                      0.9         33.59
# ..                ...          ...                      ...           ...
# 199        31-03-2023  1,45,26,000                      0.9         -0.19
# 200        31-01-2024     1,91,654                      2.2          0.06
# 201        30-10-2023  5,00,00,000                      0.9         14.20
# 202        19-01-2024    18,97,000                      0.9          1.26
# 203        18-01-2024    14,65,000                      2.2          1.23
#
#     Gross Margin Debtor Collection Creditors Payment  ... Turnover in year2  \
# 0              0             37.17             40.29  ...      13,40,81,000
# 1              0             41.40             69.23  ...      13,43,04,000
# 2           1.35             23.42             27.19  ...       2,82,65,176
# 3          40.23             27.61             67.44  ...       4,53,95,000
# 4              0             14.32             21.48  ...       3,26,51,000
# ..           ...               ...               ...  ...               ...
# 199        31.83             33.21             48.62  ...         21,27,707
# 200            0                 0                 0  ...         19,74,272
# 201        24.92             25.07             30.84  ...         13,21,720
# 202        19.11             14.02             13.46  ...         15,46,580
# 203        19.11                 0             13.90  ...         15,46,580
#
#     Turnover in year3  Total Assets Total Assets of year1  \
# 0        26,53,80,000  36,60,90,000          29,87,44,000
# 1        21,30,06,000  23,80,86,000          21,22,28,000
# 2         5,42,08,695   1,25,50,765             96,93,081
# 3         4,39,87,000   6,89,11,000           6,31,16,000
# 4         3,25,33,000   7,99,44,000           7,60,17,000
# ..                ...           ...                   ...
# 199         20,43,158     24,89,772             22,09,195
# 200         19,16,000     19,55,461             15,29,099
# 201         19,64,805     27,72,161             24,54,171
# 202         17,40,260      9,93,383              8,42,105
# 203         17,40,260      9,29,632              7,88,230
#
#     Total Assets of year2 Total Assets of year3 Number of Employees  \
# 0            27,75,88,000          30,47,45,000              87,000
# 1            19,58,97,000          22,24,85,000              66,300
# 2               54,42,881             68,15,203                 492
# 3             6,05,50,000           5,48,42,000            1,38,000
# 4             7,12,80,000           6,61,76,000              53,726
# ..                    ...                   ...                 ...
# 199             22,88,795             21,29,389               9,143
# 200             13,90,087             13,53,000                 451
# 201             22,47,214             20,53,434                   0
# 202              7,74,697              7,25,649               2,050
# 203              7,47,959              6,68,831               2,050
#
#     Number of Employees in year1 Number of Employees in year2  \
# 0                         82,000                       86,000
# 1                         64,000                       68,100
# 2                            474                          443
# 3                       1,49,000                     1,50,000
# 4                         49,345                       47,474
# ..                           ...                          ...
# 199                        8,573                        8,576
# 200                          429                           75
# 201                            0                            0
# 202                        1,817                        1,826
# 203                        1,817                        1,826
#
#     Number of Employees in year3
# 0                         83,000
# 1                         72,500
# 2                            419
# 3                       1,53,000
# 4                         46,007
# ..                           ...
# 199                        8,364
# 200                            0
# 201                        4,295
# 202                        1,679
# 203                        1,679
#
# [200 rows x 35 columns]

# %%
#remove the commas from specific columns[for change datatype into int]

# List of columns to process
columns_to_process = ['Credit limit', 'Profit before Tax', 'Profit before Tax for year1',
                      'Profit before Tax for year2', 'Profit before Tax for year3',
                      'Profit after Tax', 'Profit after Tax for year1', 'Profit after Tax for year2',
                      'Profit after Tax for year3', 'Turnover', 'Turnover in year1', 'Turnover in year2',
                      'Turnover in year3', 'Total Assets', 'Total Assets of year1', 'Total Assets of year2',
                      'Total Assets of year3', 'Number of Employees', 'Number of Employees in year1',
                      'Number of Employees in year2', 'Number of Employees in year3']

#Convert columns to string type
df2[columns_to_process] = df2[columns_to_process].astype(str)


#Remove commas from the specified columns
df2[columns_to_process] = df2[columns_to_process].replace(',', '', regex=True)

df2[columns_to_process] = df2[columns_to_process].apply(pd.to_numeric, errors='coerce')
# Out:
# C:\Users\Arth\AppData\Local\Temp\ipykernel_27036\2716635721.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[columns_to_process] = df2[columns_to_process].astype(str)
# C:\Users\Arth\AppData\Local\Temp\ipykernel_27036\2716635721.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[columns_to_process] = df2[columns_to_process].replace(',', '', regex=True)
# C:\Users\Arth\AppData\Local\Temp\ipykernel_27036\2716635721.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[columns_to_process] = df2[columns_to_process].apply(pd.to_numeric, errors='coerce')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18431 entries, 0 to 19999
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            18431 non-null  int32
#  1   Company name                  18431 non-null  object
#  2   Credit score                  18431 non-null  object
#  3   Credit score date             18431 non-null  object
#  4   Credit limit                  18431 non-null  int64
#  5   Likelihood of failure(%)      18431 non-null  object
#  6   Profit Margin                 18431 non-null  object
#  7   Gross Margin                  18431 non-null  object
#  8   Debtor Collection             18431 non-null  object
#  9   Creditors Payment             18431 non-null  object
#  10  Current Ratio                 18431 non-null  object
#  11  Liquidity Ratio               18431 non-null  object
#  12  Gearing                       18431 non-null  object
#  13  Return on Total Assets        18431 non-null  object
#  14  Company status                18431 non-null  object
#  15  Profit before Tax             18431 non-null  int64
#  16  Profit before Tax for year1   18431 non-null  int64
#  17  Profit before Tax for year2   18431 non-null  int64
#  18  Profit before Tax for year3   18431 non-null  int64
#  19  Profit after Tax              18431 non-null  int64
#  20  Profit after Tax for year1    18431 non-null  int64
#  21  Profit after Tax for year2    18431 non-null  int64
#  22  Profit after Tax for year3    18431 non-null  int64
#  23  Turnover                      18431 non-null  int64
#  24  Turnover in year1             18431 non-null  int64
#  25  Turnover in year2             18431 non-null  int64
#  26  Turnover in year3             18431 non-null  int64
#  27  Total Assets                  18431 non-null  int64
#  28  Total Assets of year1         18431 non-null  int64
#  29  Total Assets of year2         18431 non-null  int64
#  30  Total Assets of year3         18431 non-null  int64
#  31  Number of Employees           18431 non-null  int64
#  32  Number of Employees in year1  18431 non-null  int64
#  33  Number of Employees in year2  18431 non-null  int64
#  34  Number of Employees in year3  18431 non-null  int64
# dtypes: int32(1), int64(21), object(13)
# memory usage: 5.0+ MB

# %%
#change datatype of 'Credit score' and 'Credit score date'
df2['Credit score']=pd.to_numeric(df2['Credit score'],errors='coerce')
df2['Credit score date']=pd.to_datetime(df2['Credit score date'],errors='coerce')
# Out:
# C:\Users\Arth\AppData\Local\Temp\ipykernel_27036\2505221211.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Credit score']=pd.to_numeric(df2['Credit score'],errors='coerce')
# C:\Users\Arth\AppData\Local\Temp\ipykernel_27036\2505221211.py:2: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df2['Credit score date']=pd.to_datetime(df2['Credit score date'],errors='coerce')
# C:\Users\Arth\AppData\Local\Temp\ipykernel_27036\2505221211.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Credit score date']=pd.to_datetime(df2['Credit score date'],errors='coerce')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18431 entries, 0 to 19999
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            18431 non-null  int32
#  1   Company name                  18431 non-null  object
#  2   Credit score                  18431 non-null  int64
#  3   Credit score date             18431 non-null  datetime64[ns]
#  4   Credit limit                  18431 non-null  int64
#  5   Likelihood of failure(%)      18431 non-null  object
#  6   Profit Margin                 18431 non-null  object
#  7   Gross Margin                  18431 non-null  object
#  8   Debtor Collection             18431 non-null  object
#  9   Creditors Payment             18431 non-null  object
#  10  Current Ratio                 18431 non-null  object
#  11  Liquidity Ratio               18431 non-null  object
#  12  Gearing                       18431 non-null  object
#  13  Return on Total Assets        18431 non-null  object
#  14  Company status                18431 non-null  object
#  15  Profit before Tax             18431 non-null  int64
#  16  Profit before Tax for year1   18431 non-null  int64
#  17  Profit before Tax for year2   18431 non-null  int64
#  18  Profit before Tax for year3   18431 non-null  int64
#  19  Profit after Tax              18431 non-null  int64
#  20  Profit after Tax for year1    18431 non-null  int64
#  21  Profit after Tax for year2    18431 non-null  int64
#  22  Profit after Tax for year3    18431 non-null  int64
#  23  Turnover                      18431 non-null  int64
#  24  Turnover in year1             18431 non-null  int64
#  25  Turnover in year2             18431 non-null  int64
#  26  Turnover in year3             18431 non-null  int64
#  27  Total Assets                  18431 non-null  int64
#  28  Total Assets of year1         18431 non-null  int64
#  29  Total Assets of year2         18431 non-null  int64
#  30  Total Assets of year3         18431 non-null  int64
#  31  Number of Employees           18431 non-null  int64
#  32  Number of Employees in year1  18431 non-null  int64
#  33  Number of Employees in year2  18431 non-null  int64
#  34  Number of Employees in year3  18431 non-null  int64
# dtypes: datetime64[ns](1), int32(1), int64(22), object(11)
# memory usage: 5.0+ MB

# %%
#convert columns into float

float_columns = ['Likelihood of failure(%)', 'Profit Margin', 'Gross Margin', 'Debtor Collection',
                 'Creditors Payment', 'Current Ratio', 'Liquidity Ratio', 'Gearing', 'Return on Total Assets']

df2[float_columns] = df2[float_columns].replace(',', '', regex=True).astype(float)
# Out:
# C:\Users\Arth\AppData\Local\Temp\ipykernel_27036\2521305313.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[float_columns] = df2[float_columns].replace(',', '', regex=True).astype(float)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18431 entries, 0 to 19999
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            18431 non-null  int32
#  1   Company name                  18431 non-null  object
#  2   Credit score                  18431 non-null  int64
#  3   Credit score date             18431 non-null  datetime64[ns]
#  4   Credit limit                  18431 non-null  int64
#  5   Likelihood of failure(%)      18431 non-null  float64
#  6   Profit Margin                 18431 non-null  float64
#  7   Gross Margin                  18431 non-null  float64
#  8   Debtor Collection             18431 non-null  float64
#  9   Creditors Payment             18431 non-null  float64
#  10  Current Ratio                 18431 non-null  float64
#  11  Liquidity Ratio               18431 non-null  float64
#  12  Gearing                       18431 non-null  float64
#  13  Return on Total Assets        18431 non-null  float64
#  14  Company status                18431 non-null  object
#  15  Profit before Tax             18431 non-null  int64
#  16  Profit before Tax for year1   18431 non-null  int64
#  17  Profit before Tax for year2   18431 non-null  int64
#  18  Profit before Tax for year3   18431 non-null  int64
#  19  Profit after Tax              18431 non-null  int64
#  20  Profit after Tax for year1    18431 non-null  int64
#  21  Profit after Tax for year2    18431 non-null  int64
#  22  Profit after Tax for year3    18431 non-null  int64
#  23  Turnover                      18431 non-null  int64
#  24  Turnover in year1             18431 non-null  int64
#  25  Turnover in year2             18431 non-null  int64
#  26  Turnover in year3             18431 non-null  int64
#  27  Total Assets                  18431 non-null  int64
#  28  Total Assets of year1         18431 non-null  int64
#  29  Total Assets of year2         18431 non-null  int64
#  30  Total Assets of year3         18431 non-null  int64
#  31  Number of Employees           18431 non-null  int64
#  32  Number of Employees in year1  18431 non-null  int64
#  33  Number of Employees in year2  18431 non-null  int64
#  34  Number of Employees in year3  18431 non-null  int64
# dtypes: datetime64[ns](1), float64(9), int32(1), int64(22), object(2)
# memory usage: 5.0+ MB

# %%
df2.head()
# Out:
#    ID             Company name  Credit score Credit score date  Credit limit  \
# 0   1                SHELL PLC            95        2023-09-26             0
# 1   2                BP P.L.C.            95        2023-11-27      50000000
# 2   3  GLENCORE ENERGY UK LTD.            85        2023-09-29      19458000
# 3   4             UNILEVER PLC            95        2024-01-11      50000000
# 4   5            RIO TINTO PLC            99        2023-09-26      50000000
#
#    Likelihood of failure(%)  Profit Margin  Gross Margin  Debtor Collection  \
# 0                       0.9          16.78          0.00              37.17
# 1                       0.9           6.19          0.00              41.40
# 2                       0.9           0.23          1.35              23.42
# 3                       0.9          17.21         40.23              27.61
# 4                       0.9          33.59          0.00              14.32
#
#    Creditors Payment  ...  Turnover in year2  Turnover in year3  Total Assets  \
# 0              40.29  ...          134081000          265380000     366090000
# 1              69.23  ...          134304000          213006000     238086000
# 2              27.19  ...           28265176           54208695      12550765
# 3              67.44  ...           45395000           43987000      68911000
# 4              21.48  ...           32651000           32533000      79944000
#
#    Total Assets of year1 Total Assets of year2  Total Assets of year3  \
# 0              298744000             277588000              304745000
# 1              212228000             195897000              222485000
# 2                9693081               5442881                6815203
# 3               63116000              60550000               54842000
# 4               76017000              71280000               66176000
#
#    Number of Employees  Number of Employees in year1  \
# 0                87000                         82000
# 1                66300                         64000
# 2                  492                           474
# 3               138000                        149000
# 4                53726                         49345
#
#    Number of Employees in year2  Number of Employees in year3
# 0                         86000                         83000
# 1                         68100                         72500
# 2                           443                           419
# 3                        150000                        153000
# 4                         47474                         46007
#
# [5 rows x 35 columns]
